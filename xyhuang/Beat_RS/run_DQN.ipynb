# %% [markdown]
# # Reinforcement learning for Hamiltonian engineering

# %% [markdown]
# ## Set environment

# %%
# import import_ipynb, 
from tqdm import tqdm
import time, sys, os
from copy import deepcopy as dcp
# from RL_funcs import Hamiltonian, Q_table_ML, getPPstr, dec2base
import gym
import gym_pp
from scipy.linalg import expm
from scipy import sparse
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt
# plt.rc('text', usetex=True)
# font = {'family' : 'normal',
#  'weight' : 'bold',
#  'size' : 50}
# plt.rc('font', **font)
# from jupyterthemes import jtplot
# jtplot.style()

sys.path.append(os.path.abspath(os.path.join('DQN_pkg')))
from DQN import DeepQNetwork # added

# %%
# 10-base to arbitrary base
def dec2base(num,base,length):
    s=''
    if num>base**length-1:
        raise ValueError('Input number exceeds the maximum number allowed by the length')
    for i in range(length):
        s=s+chr(ord('0')+int(num/(base**(length-1-i))))
        num=num-int(num/(base**(length-1-i)))*(base**(length-1-i))
    return s

# given a state dict, return a str that specifies all pulses
def getPPstr(state,actionDict=['d','x','y','-x','-y']):
    num=state['pp']
    base=len(actionDict)
    length=state['n']
    rawPulseStr=dec2base(num,base,length)
    pulseStr=''
    for p in rawPulseStr:
        pulseStr=actionDict[int(p)]+','+pulseStr
    pulseStr=pulseStr[0:-1]
    return pulseStr

def Pauli(n):
    if n==0:
      return np.eye(2)
    elif n==1:
      return np.array([[0,1],[1,0]])
    elif n==2:
      return np.array([[0,-1j],[1j,0]])
    elif n==3:
      return np.array([[1,0],[0,-1]])
    else:
      raise ValueError('Input must be integer from 0 to 3.')

# returns sigma_a^p*sigma_b^q, with a,b = 1,2,3, p,q being position
def Kron2body(N_atom,a,b,p,q):
    y=1
    for i in range(N_atom):
        if i==p:
            y=np.kron(y,Pauli(a))
        elif i==q:
            y=np.kron(y,Pauli(b))
        else:
            y=np.kron(y,np.eye(2))
    return y

def Hamiltonian(N_atom,bc,cplist,model):
    H=np.zeros((2**N_atom,2**N_atom))
    for pp in range(len(cplist)):
        for p in range(N_atom):
            if bc=='p':
                q=(p+pp+1)%N_atom
            elif bc=='o':
                q=p+pp+1
                if q>=N_atom:
                    continue
            H=H+cplist[pp]*(model[0]*Kron2body(N_atom,1,1,p,q)
                            +model[1]*Kron2body(N_atom,2,2,p,q)
                            +model[2]*Kron2body(N_atom,3,3,p,q))
    if np.max(np.abs(np.imag(H)))<1e-10:
        H=np.real(H)
    return H

# %%
def action_transform(pulses, maxTime):
    input_array = np.zeros((maxTime, 6))
    for pulse_index in range( min( len(pulses['pp']), maxTime ) ):
        input_array[ pulse_index, pulses['pp'][pulse_index]] = 1

    return input_array.flatten()

def one_episode(env, RL, maxTime, epsilon=None):
    observation, info = dcp( env.reset() )
    observation = dcp( env.pulses )
    done = False
    i=0
    state_array=[]
    action_array=[]
    reward_array=[]
    next_state_array=[]
    reward=0
    while not done:
        if np.max(np.abs( env.frame-np.eye(2) )) > 1e-10 or observation['n']==0:
            action_no_5 = True
        else:
            action_no_5 = False
        env.render()
        action = RL.choose_action(action_transform(observation, maxTime), epsilon)
        while action_no_5 and action == 5:
            action = RL.choose_action(action_transform(observation, maxTime), epsilon)
        observation_, reward, done, info = dcp( env.step(action) )
        observation_ = dcp( env.pulses )
        if observation_['n'] == maxTime:
            observation_, reward, done, info = dcp( env.step(5) )
            observation_ = dcp( env.pulses )
#         RL.store_transition(action_transform(observation, maxTime), action, reward, \
#                             action_transform(observation_, maxTime))
        state_array.append(action_transform(observation, maxTime))
        action_array.append(action)
        reward_array.append(reward)
        next_state_array.append(action_transform(observation_, maxTime))
        observation = dcp( observation_ )
        i=i+1
    for k in range(i):
        if reward>25:
#             print("elite")
            RL.elite_store_transition(state_array[k], action_array[k], reward_array[k], next_state_array[k])
        RL.store_transition(state_array[k], action_array[k], reward_array[k], next_state_array[k])
        
    
    return reward

def DQN_1run(env, RL, maxTime, break_reward, epsilon=None, lr=None):
    total_steps = 0
    best_reward=0
    best_pp=None
    reward_list=[]

    RL.reset()
    for episode in range(nEpisodes):
        reward = one_episode(env, RL, maxTime, epsilon=None)
#         if episode > batch_size :# and total_steps%5==0:
        if episode < nEpisodes-0*5e5:
            RL.learn(alpha=lr)
        else:
            RL.learn(alpha=lr,ifelite=True)

        if reward>best_reward:
            best_reward=reward
            best_pp=getPPstr(env.state)
            print("Episode: "+str(episode))
            print(reward)
            print(getPPstr(env.state))
#             print("1-Fidelity= +str(1-env.getFidelity())+', Reward: '+str(reward))
        if reward > break_reward:
            return episode, reward_list
            break
        reward_list.append(reward)
#     print("Best sequece: "+best_pp)
    print(best_pp)
    return episode, reward_list

# %% [markdown]
# ## Set parameters

# %%
env = gym.make('pp-v0')



observation = env.reset()

maxTime=12
nSpin=3
pw=0.0
env.setParam(maxTime,nSpin,pw)

env.setTarget(np.eye(2**env.nSpin), false_frame=-10)


H=Hamiltonian(nSpin,'p',[1],[-0.5,-0.5,1])
J=8.18e-3
t=1
env.setU0(expm(-1j*J*H*t))
env.setH0(J*H) 

env = env.unwrapped

# %% [markdown]
# ## learning

# %%
nEpisodes=int(1e5)
alpha=0.00025 # gradient step
gamma=0.99 # discount factor
e_greedy_max = 0.99
e_greedy_incre = e_greedy_max/nEpisodes*2
node_each_layer = [100] * 1
replace_target_iter, memory_size, batch_size=1000, int(1e5), 32
n_run = 75

RL = DeepQNetwork(n_actions=env.action_space.n,
                  n_features=maxTime*6, maxTime=maxTime,
                  learning_rate=alpha, reward_decay=gamma, e_greedy=e_greedy_max,
                  replace_target_iter=replace_target_iter, memory_size=memory_size, batch_size=batch_size,
                  e_greedy_increment=e_greedy_incre, node_each_layer = node_each_layer)
#'''

best_episode = []
start_t = time.clock()
# for run_index in range(n_run):
#     print('\n run_index=', run_index)
#     best_episode.append( DQN_1run (env, RL, maxTime, 13, lr=0) )
    

for run_index in range(n_run):
    print("\n run_index=", run_index)
    best, reward_list= DQN_1run (env, RL, maxTime, 28.6) 
    best_episode.append( best)

print(best_episode[:n_run])
print(best_episode[n_run:])
print('time='+ str(time.clock() - start_t))
np.savetxt('DQNbeatrs.csv',np.array([best_episode]).T,fmt=['%.7f'],delimiter=',',header="episode")
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead
#  run_index= 0
# Episode: 9
# 10.187653510077515
# -y,y
# Episode: 35
# 10.188105333113942
# x,d,-x,d
# Episode: 58
# 11.286759305013568
# x,y,-y,-y,y,-x
# Episode: 72
# 11.286759305057844
# -x,-y,y,x,-x,x
# Episode: 108
# 27.215159259650505
# -x,y,-y,x,y,-y
# Episode: 2677
# 27.21552557343899
# x,-y,y,-x,y,-y
# Episode: 11142
# 28.597943818980777
# -y,x,d,x,-y,d,y,-y,-x,-y,y,-x
# Episode: 12151
# 28.60233299939954
# y,-x,y,y,x,x,y,-x,-x,-y,x,-y
#
#  run_index= 1
# Episode: 17
# 10.187653510077515
# -x,x
# Episode: 22
# 12.021278293381492
# x,-x,y,d,-y
# Episode: 76
# 13.404110982967753
# -y,-y,-y,x,y,-y,y,y,x,y
# Episode: 321
# 27.21559885230173
# -y,-y,y,-y,-x,-y,-y,x,x,y,-y,x
# Episode: 6834
# 28.60028231756181
# -x,x,d,y,-x,-y,-y,-x,d,-x,x,y
#
#  run_index= 2
# Episode: 14
# 12.02127829339995
# d,x,-y,y,-x
# Episode: 27
# 12.674255256008935
# -x,-x,-x,-y,d,-y,d,-y,x,-x,-y,-x
# Episode: 123
# 18.701957454227124
# d,-y,x,-y,x,y,y,-x,x,y,d,x
# Episode: 293
# 27.215159259650505
# y,y,x,-y,-y,x
# Episode: 3825
# 27.215305769063995
# -x,-y,y,x,-y,y
# Episode: 4051
# 28.599112384699495
# -x,-x,-y,x,-y,x,-x,-y,-x,x,-x,y
# Episode: 5551
# 28.599989706001566
# y,x,y,-y,-x,y,x,-y,y,-x,-y,-y
# Episode: 15869
# 28.601746661065533
# -x,y,-x,x,-y,-y,-x,y,y,-x,-y,x
#
#  run_index= 3
# Episode: 5
# 12.672448531730941
# y,-x,y,-x,d,x,y,x,x,d,x,y
# Episode: 47
# 12.673050532166643
# -y,y,x,y,d,-y,x,d,-x,-x,x,-x
# Episode: 50
# 26.656422850344224
# x,y,y,x,x,d,-x,-y,d,-y,-y,y
# Episode: 1002
# 28.599112384699495
# y,d,y,-y,-x,-y,-y,-x,y,-x,d,x
# Episode: 5286
# 28.6026262975392
# d,-x,y,y,-y,x,-y,y,-x,d,-y,x
#
#  run_index= 4
# Episode: 0
# 20.0881012561942
# -x,y,x,x,x,-y,-x,x,y,y,-x,y
# Episode: 1244
# 28.603506708454468
# y,-x,-x,y,-y,-y,-x,y,y,x,-x,x
#
#  run_index= 5
# Episode: 0
# 9.900025819363979
# -x,d,x
# Episode: 7
# 10.187653510077515
# -x,x
# Episode: 20
# 10.188105333113942
# y,d,-y,d
# Episode: 34
# 12.211483985918532
# x,d,-x,-y,-y,-x,y,-y,y,y,-x
# Episode: 247
# 20.896827231629945
# -y,-y,-y,x,x,y,x,d,x
# Episode: 755
# 28.60380035109349
# x,-x,-y,-y,y,-x,-y,-y,x,x,x,-y
#
#  run_index= 6
# Episode: 5
# 13.404110984365714
# -y,-x,d,-x,x,-x,-y,x,x,d
# Episode: 263
# 27.215159259650505
# -y,-x,y,-y,x,y
# Episode: 2102
# 28.60380035109349
# y,y,y,x,-x,y,x,x,x,y,-y,x
#
#  run_index= 7
# Episode: 3
# 8.801246225071123
# d,d
# Episode: 6
# 9.900025819368404
# -y,d,y
# Episode: 10
# 10.187653510071616
# y,-y,y,-y
# Episode: 12
# 18.70120517898922
# y,-x,-y,-x,y,x
# Episode: 938
# 20.08569808695917
# -x,-x,-x,x,-y,x,-x,d,x,x,-y,d
# Episode: 1037
# 25.828938150554233
# d,-x,-y,d,y,x
# Episode: 1737
# 27.215159259650505
# -x,-y,-x,x,y,x
# Episode: 2427
# 27.215305769063995
# -x,-x,y,x,x,y
# Episode: 3456
# 28.601453620770393
# d,y,x,-x,y,-x,d,-y,-y,-x,-y,y
#
#  run_index= 8
# Episode: 13
# 10.151680934812452
# -y,d,d,d,x,-x,y,y,-y
# Episode: 26
# 10.187653510092266
# x,-x
# Episode: 57
# 10.265379878437006
# -y,x,d,-x,d,d,d,x,-x,d,y
# Episode: 61
# 11.574540763428274
# x,-x,y,-y
# Episode: 229
# 12.019020921996061
# d,y,-x,y,y,-y,-y,d,x,-y
# Episode: 323
# 12.670645066914854
# -y,y,-y,-x,x,x,y,d,-y,-x,y,d
# Episode: 387
# 20.088100962069365
# x,y,-x,-x,-x,-y,x,x,-y,y,x,-y
# Episode: 676
# 28.601746661065533
# x,y,-x,y,-y,-x,y,-y,x,-x,y,x
#
#  run_index= 9
# Episode: 3
# 10.187653510077515
# -y,y
# Episode: 8
# 20.086897010784284
# -y,-y,x,d,x,y,x,y,x,d,-y,x
# Episode: 316
# 20.0881012561942
# x,y,-x,y,x,x,x,y,-x,-x,y,-y
# Episode: 549
# 27.215159259650505
# -y,x,-y,y,-x,y
# Episode: 1922
# 27.215305769063995
# -y,-x,x,y,-x,x
# Episode: 2489
# 28.603506708454468
# -y,-y,-y,x,x,-y,x,x,x,-y,-y,x
#
#  run_index= 10
# Episode: 7
# 8.801246225071123
# d
# Episode: 9
# 10.187653510074567
# x,-x,x,-x
# Episode: 54
# 10.187653510077515
# -y,y
# Episode: 88
# 11.285405183646223
# -y,-x,x,x,x,x,d,d,-y,-x,-y,-x
# Episode: 120
# 12.673049444177138
# x,x,-x,-x,x,-y,-x,-x,-y,-y,y,x
# Episode: 135
# 12.693618667276018
# -y,-y,-x,y,y,d,-x
# Episode: 391
# 28.600867797672212
# x,d,y,-x,x,-y,-x,d,-y,x,-x,y
#
#  run_index= 11
# Episode: 0
# 10.187653510077515
# y,-y
# Episode: 22
# 11.57373834082046
# d,-y,x,-y,-x,-x,x,d,y,-x,-y,y
# Episode: 41
# 25.82879165187246
# d,-y,x,d,-x,y
# Episode: 2124
# 27.215305769063995
# x,x,-y,-x,-x,-y
# Episode: 4565
# 28.5996971800378
# y,-x,-x,y,d,x,y,-x,x,-y,d,x
# Episode: 8978
# 28.60233299939954
# y,y,-x,-y,y,x,x,-y,-x,x,-y,x
#
#  run_index= 12
# Episode: 3
# 8.801246225071123
# d,d
# Episode: 6
# 10.187653510077515
# y,-y
# Episode: 10
# 10.999630529125685
# y,y,-y,-x,d,x,d,d,-y
# Episode: 36
# 13.404110983335636
# x,-y,y,-y,-y,x,y,-y,y,y
# Episode: 92
# 26.655083153250274
# y,y,-x,-y,d,x,y,d,-y,-x,-y,-x
# Episode: 241
# 27.215159259650505
# x,-x,y,-x,x,-y
# Episode: 2631
# 27.215452299945643
# -y,-x,y,y,-x,-y
# Episode: 5677
# 27.216625320608003
# -x,d,-y,x,-x,-x,x,-y,d,-x,y,y
# Episode: 6084
# 28.604094079983838
# -x,-x,y,y,x,y,-y,y,x,-x,y,-x
#
#  run_index= 13
# Episode: 15
# 10.187653510077515
# y,-y
# Episode: 31
# 11.652800259174889
# d,-x,-x,-y,d,d,-y,x,x,-y,-y
# Episode: 67
# 12.671246343265286
# d,y,-x,x,-x,-y,x,-x,-x,y,x,d
# Episode: 181
# 12.67365253110292
# x,x,-x,y,-y,-x,y,-y,-x,x,-y,y
# Episode: 410
# 12.693618667276018
# x,x,-y,d,-x,-x,-y
# Episode: 444
# 20.899233438946368
# y,d,x,y,-y,x,y,-x,-x
# Episode: 857
# 27.215159259650505
# x,y,-y,-x,-y,y
# Episode: 1250
# 27.215452299945643
# -x,-y,x,-x,y,x
# Episode: 4307
# 28.60233299939954
# -y,-y,y,x,-y,y,-x,-x,x,y,-x,x
#
#  run_index= 14
# Episode: 4
# 10.187653510077515
# -y,y
# Episode: 43
# 12.6918136659311
# -x,y,x,d,x,y,-x
# Episode: 142
# 12.959627808419338
# -x,-x,x,x,y,x,-x,-y
# Episode: 215
# 18.70195774839633
# y,-x,x,x,d,y,d,x,-x,-y,-x,-y
# Episode: 332
# 20.086297721508252
# y,y,y,-x,-x,-x,-y,y,y,y,x,-y
# Episode: 833
# 27.216918790896244
# -y,x,x,d,x,-x,-y,-x,x,d,-x,-x
# Episode: 2172
# 28.6026262975392
# d,y,-x,-y,-y,x,d,x,-x,-y,-x,-x
#
#  run_index= 15
# Episode: 1
# 8.801246225071123
# d
# Episode: 20
# 10.074950359988545
# d,d,-y,d,y
# Episode: 24
# 10.187653510077515
# y,-y
# Episode: 38
# 12.67365253110292
# -y,-x,-x,y,y,-x,-y,y,x,-x,-x,-y
# Episode: 161
# 12.961434712729071
# -y,x,-x,y,-x,x,y,-y
# Episode: 259
# 13.595782219243343
# -x,d,x,-x,-x,-y,-y,-y,-x,-x,y
# Episode: 275
# 27.215305769063995
# y,-y,x,y,-y,-x
# Episode: 1705
# 28.601160666322716
# x,y,-x,-y,-y,-x,y,-y,-x,x,y,-x
#
#  run_index= 16
# Episode: 6
# 12.671845447156867
# y,d,x,-x,x,d,-x,-y,-x,x,y,-y
# Episode: 122
# 27.21508601299235
# d,y,-x,y,-y,x,d,x,y,-y,-x,-y
# Episode: 745
# 27.215159259650505
# -x,x,-y,x,-x,y
# Episode: 3020
# 27.215232511674124
# x,-x,-y,-x,x,y
# Episode: 3875
# 27.215305769063995
# x,-x,-y,x,-x,y
# Episode: 5314
# 28.60233299939954
# y,-x,-y,y,x,-x,-y,-x,-x,y,x,y
#
#  run_index= 17
# Episode: 5
# 9.900025819363979
# -x,x,d
# Episode: 22
# 10.71121024436976
# y,-y,x,-x,-y,y,d,y,-y
# Episode: 31
# 11.574540763440082
# y,-y,x,-x
# Episode: 112
# 27.215452299945643
# y,-x,-y,-y,-x,y
# Episode: 8122
# 27.215745426138565
# x,y,y,-x,-y,-y,-y,y,-x,-y,y,-x
# Episode: 8795
# 27.216625320608003
# d,y,x,x,y,d,-x,y,y,-y,-y,-x
# Episode: 9353
# 28.602919681727894
# y,-y,x,-x,y,-x,-x,x,y,-y,x,-y
#
#  run_index= 18
# Episode: 2
# 13.599398748501613
# y,x,d,-y,-x,d,x,-y,x,y,d
# Episode: 286
# 20.899233836095235
# y,-y,x,-y,-x,x,y,d,-x
# Episode: 638
# 27.21552557343899
# -x,y,-y,x,-y,y
# Episode: 5202
# 28.60028231756181
# -x,-y,-y,x,-y,y,y,x,y,-y,x,-y
#
#  run_index= 19
# Episode: 0
# 8.801246225071123
# d
# Episode: 22
# 11.575142942476905
# d,x,d,x,-y,-y,y,y,-x,-x,-y,y
# Episode: 49
# 12.673652531032038
# x,x,-y,-y,x,-x,y,-y,-y,x,x,y
# Episode: 86
# 13.402313832473109
# y,d,-x,y,d,x,-y,y,-y,x
# Episode: 134
# 17.891322540834164
# -x,y,x,-y,d,x,-x,x,y,y,-y,d
# Episode: 136
# 18.701205076107442
# x,-y,x,y,-x,y
# Episode: 956
# 20.086899067182653
# -y,-x,y,y,-x,x,d,-x,-y,y,-y,d
# Episode: 1981
# 28.601746661065533
# -y,-x,-y,-x,x,y,-x,x,-y,y,x,y
#
#  run_index= 20
# Episode: 3
# 10.187653510077515
# -y,y
# Episode: 13
# 18.70195766014556
# x,y,x,-y,-x,x,-x,y,-y,-y,-x,x
# Episode: 282
# 27.215159259650505
# y,-y,x,-y,y,-x
# Episode: 299
# 27.21559885230173
# y,-x,-x,-y,y,x,x,-y,x,x,-x,-x
# Episode: 950
# 28.597651890793035
# y,-x,x,d,x,y,d,-y,-x,-y,x,-x
# Episode: 2453
# 28.597943818980777
# y,-x,-x,-y,-x,-x,d,x,y,d,y,x
# Episode: 2517
# 28.601746661065533
# y,x,x,y,-x,-x,-y,-x,-y,y,x,y
#
#  run_index= 21
# Episode: 9
# 9.900025819361765
# d,y,-y
# Episode: 28
# 10.187653510071616
# -y,y,-y,y
# Episode: 32
# 10.187653510074567
# x,x,-x,-x
# Episode: 40
# 27.21508601299235
# -y,-x,-y,y,x,y
# Episode: 488
# 27.215232511674124
# -y,-x,x,y,x,-x
# Episode: 809
# 28.60380035109349
# x,x,y,-y,y,-x,-y,y,x,-x,-x,y
#
#  run_index= 22
# Episode: 3
# 10.187653510074567
# -x,x,-x,x
# Episode: 10
# 25.828828274530903
# -y,d,y,-x,d,x
# Episode: 790
# 27.215012771698877
# -y,y,x,-y,y,-x
# Episode: 1200
# 27.215232511674124
# x,-y,x,y,x,-x,y,-x,-y,-x,y,y
# Episode: 1429
# 28.5996971800378
# x,y,x,-x,-y,d,x,y,-x,-x,y,d
# Episode: 2927
# 28.603506708454468
# y,-x,-x,x,y,-x,x,-y,-y,y,x,-y
#
#  run_index= 23
# Episode: 5
# 9.900025819363979
# x,-x,d
# Episode: 17
# 11.57454076340466
# x,-y,y,-x
# Episode: 81
# 12.098438015717639
# d,x,d,-x,-y,d,y,-y,y
# Episode: 153
# 12.670645790357856
# -y,-x,-x,x,d,-y,d,x,y,x,-x,x
# Episode: 372
# 13.407720445498322
# -y,y,-y,y,-x,y,-y,x,-x,x
# Episode: 409
# 27.215159259650505
# y,-y,x,-y,y,-x
# Episode: 2645
# 27.215232511674124
# y,-x,-x,y,x,x
# Episode: 3476
# 27.215452299945643
# -y,x,y,y,x,-y
# Episode: 4801
# 28.5996971800378
# d,x,y,-x,x,-y,d,-x,y,x,-x,-y
# Episode: 9730
# 28.603213152016135
# -y,x,-y,y,x,x,x,-y,x,-x,-y,-y
#
#  run_index= 24
# Episode: 9
# 3.4459093502284586
# y,d,d,y,d,-x,x,-x,d,-y,-y,-x
# Episode: 12
# 10.634274878446481
# -y,y,x,-x,d
# Episode: 14
# 12.021278293436866
# -y,y,x,d,-x
# Episode: 292
# 20.08449766815816
# x,y,-y,-y,x,-x,d,y,x,d,-x,-x
# Episode: 554
# 20.08689924344557
# y,x,-y,d,-y,-y,y,x,d,-x,x,y
# Episode: 1483
# 20.08810196209416
# y,y,x,-y,-x,x,-y,y,-y,-x,x,x
# Episode: 1669
# 27.215159259650505
# -x,-x,-y,x,x,-y
# Episode: 2444
# 27.215745426138565
# y,-y,-y,y,-x,y,-y,-x,x,-y,y,x
# Episode: 5227
# 28.59940473962045
# -y,x,y,y,-x,y,y,y,x,y,y,-x
# Episode: 13261
# 28.601160666322716
# y,-x,-x,-y,-x,-x,y,-x,-y,y,x,y
#
#  run_index= 25
# Episode: 2
# 11.651251808828851
# d,-y,y,-y,x,-y,-x,-x,-y,x,y
# Episode: 136
# 13.599396571512179
# y,d,-y,-x,-x,-y,x,x,-y,x,-x
# Episode: 273
# 18.701356029758518
# -y,y,d,-x,x,-x,y,-y,y,d,-y,x
# Episode: 909
# 20.089306717976065
# y,-x,y,x,-x,-x,x,-y,d,d,x,-y
# Episode: 1342
# 27.215452299945643
# -y,-x,y,y,-x,-y
# Episode: 2987
# 27.215745426138565
# x,x,-x,-y,-x,x,y,y,-x,x,-y,-x
# Episode: 4003
# 28.60028231756181
# -y,y,-x,y,-y,-y,x,y,-y,x,-y,-x
#
#  run_index= 26
# Episode: 8
# 10.187653510077515
# -y,y
# Episode: 25
# 10.187653510092266
# x,-x
# Episode: 44
# 11.574741651187683
# y,x,d,-x,d,-x,-x,-x,y,y,x,y
# Episode: 76
# 12.671846895073712
# -y,x,x,x,d,d,-y,-x,x,-y,-x,-y
# Episode: 130
# 18.701205061410047
# y,-x,y,x,-y,x
# Episode: 218
# 18.70120512019963
# -y,x,y,-x,y,x
# Episode: 405
# 20.896827231629945
# d,x,-y,-y,y,-x,x,y,-x
# Episode: 918
# 28.59940473962045
# -x,x,-y,-x,y,x,x,y,x,-x,-x,y
# Episode: 9657
# 28.601160666322716
# x,y,x,-y,-y,x,y,y,-x,-x,y,x
#
#  run_index= 27
# Episode: 4
# 11.575444077378602
# -y,y,-y,y,-x,d,x,d
# Episode: 31
# 13.405916802023766
# d,-x,y,x,y,-y,-x,d,-y,x
# Episode: 1043
# 18.701205149594426
# y,x,-y,-x,-y,x
# Episode: 1115
# 25.828846586363092
# -x,d,x,y,d,-y
# Episode: 3711
# 27.215159259650505
# -y,-x,y,-y,x,y
# Episode: 3734
# 28.599989706001566
# -y,y,-y,x,-y,y,x,-y,-x,y,-y,-x
# Episode: 7202
# 28.601453620770393
# x,-x,-y,-x,x,-x,y,d,y,-x,d,-y
#
#  run_index= 28
# Episode: 3
# 10.187653510077515
# -x,x
# Episode: 23
# 11.6530583598314
# y,-x,x,d,-x,-y,y,d,x,d,-y
# Episode: 24
# 12.96143471287085
# -y,y,x,-x,x,-y,y,-x
# Episode: 31
# 13.599395482616739
# -x,-x,-y,x,-x,y,y,x,x,y,d
# Episode: 55
# 25.82879165187246
# d,-y,x,d,-x,y
# Episode: 2251
# 27.215159259650505
# -y,-y,x,y,y,x
# Episode: 2672
# 27.215452299945643
# y,-x,-y,-y,-x,y
# Episode: 15603
# 27.21699217192728
# d,x,-x,-y,x,-x,d,x,-x,y,-x,x
# Episode: 16383
# 28.60028231756181
# y,y,x,-y,-y,x,-y,-x,y,y,-x,-y
#
#  run_index= 29
# Episode: 0
# 9.628090182972684
# d,y,-y,d
# Episode: 14
# 10.188105333113942
# x,d,-x,d
# Episode: 16
# 11.5745402798867
# x,x,-y,y,-x,-y,-y,d,y,y,d,-x
# Episode: 26
# 12.690011916494585
# y,x,d,y,-x,-y,-x
# Episode: 153
# 20.088101315019177
# -y,x,d,-y,x,y,y,x,-x,y,x,d
# Episode: 162
# 27.215672136534664
# -x,-x,y,-x,x,-x,x,y,-x,-x,-y,-y
# Episode: 1620
# 28.60028231756181
# -y,x,d,y,-x,x,y,x,d,-y,x,-x
#
#  run_index= 30
# Episode: 0
# 11.28736166507843
# d,-x,y,-y,d,x
# Episode: 12
# 12.212387879511386
# -x,-y,d,y,-x,x,y,-y,x,-x,x
# Episode: 14
# 13.407720445498322
# x,-x,-x,y,-y,-y,-y,-x,y,y
# Episode: 74
# 13.40772153350143
# y,x,-x,y,x,-x,-y,-y,-x,x
# Episode: 350
# 13.593981553928366
# -x,-x,-y,y,y,x,d,x,y,-x,x
# Episode: 560
# 18.701957424810207
# x,-y,-x,y,-x,x,-y,y,-x,d,-y,d
# Episode: 567
# 20.08810243269441
# -x,-y,d,y,-x,-y,y,y,-y,x,d,x
# Episode: 1860
# 28.600867797672212
# d,-x,x,-y,-x,-x,d,y,-x,-y,-y,x
#
#  run_index= 31
# Episode: 4
# 10.187653510083416
# -x,x,x,-x
# Episode: 15
# 12.671847981543378
# -x,-y,x,y,-y,-y,-x,d,y,x,d,-x
# Episode: 139
# 20.088704217465985
# y,y,-x,d,-y,-y,-x,y,-x,x,-y,d
# Episode: 400
# 25.828828274530903
# y,d,-y,x,d,-x
# Episode: 1347
# 27.215305769063995
# x,-y,-x,-x,-y,x
# Episode: 12279
# 28.5996971800378
# y,-x,-x,y,x,x,x,y,-x,x,-y,-x
# Episode: 17751
# 28.602919681727894
# y,x,x,x,-y,x,x,y,y,-y,x,y
#
#  run_index= 32
# Episode: 5
# 9.62809018297437
# d,d,-y,y
# Episode: 28
# 10.187653510077515
# -x,x
# Episode: 30
# 12.695426932035963
# y,y,-y,-x,d,x,-y
# Episode: 167
# 13.593982637211415
# x,y,-x,-y,y,d,x,-y,-y,y,-x
# Episode: 360
# 27.215305769063995
# x,x,-y,-x,-x,-y
# Episode: 847
# 28.60057501476864
# x,y,x,-y,-x,-x,-y,-x,x,x,-y,-x
#
#  run_index= 33
# Episode: 2
# 12.096032196191473
# y,-y,x,-y,d,-x,-y,x,y
# Episode: 11
# 12.693618667239862
# -y,x,-y,y,-x,d,y
# Episode: 14
# 28.59823583241547
# x,x,-y,x,x,d,x,y,d,y,x,y
# Episode: 5793
# 28.60233299939954
# y,-x,x,y,x,x,y,-x,-y,y,-x,-y
#
#  run_index= 34
# Episode: 0
# 8.801246225071123
# d,d
# Episode: 3
# 12.69181366600328
# y,-x,d,x,-y,x,-x
# Episode: 64
# 27.215305769063995
# -y,-y,x,x,y,-x,x,x,-x,y,x,x
# Episode: 3182
# 27.21655196649097
# -y,d,x,-y,y,y,y,x,d,-y,x,-x
# Episode: 12695
# 28.601453620770393
# -x,y,y,x,d,-y,x,d,x,y,-y,y
#
#  run_index= 35
# Episode: 1
# 9.900025819361765
# d,-y,y
# Episode: 15
# 11.28736166506957
# -x,x,d,-y,d,y
# Episode: 17
# 11.575544394770919
# x,d,x,-y,y,y,-y,d,-y,y,-x,-x
# Episode: 37
# 12.671847619209805
# x,-y,d,y,x,d,y,-y,-y,-x,-x,-y
# Episode: 69
# 12.674254166991613
# d,y,y,x,-x,y,-y,-x,-y,-y,d,-x
# Episode: 159
# 20.086297545351332
# x,-x,y,-y,y,-x,x,-x,x,-y,-x,x
# Episode: 426
# 20.086897715834677
# -y,-x,-x,y,x,y,x,y,-x,y,x,-x
# Episode: 501
# 20.089306482392374
# x,d,x,-y,y,y,d,-x,-y,y,-x,y
# Episode: 733
# 20.089908697740555
# -y,d,y,x,d,x,-x,y,-x,-y,-x,y
# Episode: 1241
# 27.215159259650505
# -x,-y,-x,x,y,x
# Episode: 2398
# 27.215452299945643
# -x,-y,x,-x,y,x
# Episode: 5905
# 27.21655196649097
# -x,x,y,d,-x,-y,y,-x,d,y,x,x
# Episode: 6662
# 28.599112384699495
# d,x,y,x,-x,-y,d,-x,-y,x,-x,y
# Episode: 13219
# 28.603506708454468
# -x,x,y,y,x,y,-y,-y,-x,x,-y,x
#
#  run_index= 36
# Episode: 0
# 2.8834366124053394
# y,d,d,-y,x,d,-x,d
# Episode: 2
# 9.900025819361765
# d,y,-y
# Episode: 5
# 12.6918136659311
# -y,x,d,x,-y,-x,-x
# Episode: 115
# 13.402314914462785
# y,-y,x,d,y,-x,-y,-x,y,d
# Episode: 383
# 20.894426668503716
# -y,-x,x,x,x,-y,-x,-x,d
# Episode: 584
# 27.215159259650505
# -x,x,-y,x,-x,y
# Episode: 2690
# 27.215305769063995
# -x,-y,x,x,-y,-x
# Episode: 2985
# 28.60380035109349
# x,-y,y,x,y,-y,-y,-x,-x,-y,x,-x
#
#  run_index= 37
# Episode: 1
# 8.801246225071123
# d
# Episode: 8
# 11.574541488876864
# x,-x,d,d,-y,-y,-x,-y,x,y,x,y
# Episode: 42
# 12.673049444318817
# -y,x,y,y,y,y,-y,-y,x,-x,x,-y
# Episode: 78
# 20.08569861511332
# y,-y,d,-y,y,x,-y,y,-y,y,d,-x
# Episode: 888
# 25.828864898530615
# d,y,x,d,-x,-y
# Episode: 1181
# 27.215305769063995
# -x,x,y,-x,x,-y
# Episode: 1663
# 28.5996971800378
# -x,-y,-y,-x,y,d,-x,-y,y,x,y,d
# Episode: 1727
# 28.602919681727894
# x,x,-x,y,x,x,y,-y,-y,-x,-y,-y
#
#  run_index= 38
# Episode: 11
# 12.6760623402441
# -y,y,d,-x,x,-y,d,-x,x,-x,x,y
# Episode: 143
# 13.402310585115655
# d,y,x,-x,x,d,-x,-y,-x,x
# Episode: 413
# 13.601197202660483
# y,d,-y,-y,y,x,d,d,-x,-x,x
# Episode: 424
# 20.896827495759524
# x,-y,y,y,-x,-x,y,x,d
# Episode: 547
# 27.215159259650505
# -y,-y,x,y,y,x
# Episode: 1021
# 27.21552557343899
# -x,-x,y,-y,-x,y,-y,-y,-y,x,-y,-y
# Episode: 3178
# 27.217359157875837
# d,-y,-x,x,x,y,d,y,-x,x,x,-y
# Episode: 6724
# 28.602039787258455
# -y,d,-x,x,-y,-x,-x,d,-x,-y,-y,x
#
#  run_index= 39
# Episode: 10
# 10.395753987871245
# d,d,-y,y,-x,-x,x,x
# Episode: 21
# 11.574540763416467
# -x,x,y,-y
# Episode: 165
# 13.40772262194878
# y,y,-x,-y,x,-y,-y,x,y,-x
# Episode: 193
# 18.701957763104794
# d,x,-x,-y,x,y,-y,-x,-x,x,d,y
# Episode: 491
# 18.702559844034788
# d,x,y,-y,-y,d,-x,-y,x,y,-x,x
# Episode: 1008
# 28.59940473962045
# y,-x,-y,y,y,x,-y,-y,x,-y,-x,y
# Episode: 9113
# 28.601453620770393
# x,x,-y,d,-y,-y,x,y,-y,d,x,y
#
#  run_index= 40
# Episode: 2
# 10.187653510092266
# x,-x
# Episode: 37
# 12.021278293436866
# y,-y,-x,d,x
# Episode: 48
# 12.695424752602424
# -x,d,x,y,d,-y,d
# Episode: 209
# 12.963241615878879
# y,-y,-y,x,d,d,-x,y
# Episode: 387
# 20.08689730455522
# y,x,d,y,x,-y,y,-x,d,-x,-y,-x
# Episode: 1244
# 27.215232511674124
# -x,x,y,x,-x,-y
# Episode: 4658
# 28.603506708454468
# x,-x,-x,-y,-x,x,y,-y,y,x,-y,y
#
#  run_index= 41
# Episode: 1
# 10.187653510077515
# y,-y
# Episode: 17
# 11.574541488876864
# x,-x,d,-y,-x,-y,x,x,d,-y,-x,y
# Episode: 42
# 12.691811494249944
# y,-x,d,x,-y,d,d
# Episode: 129
# 27.215159259650505
# y,x,-y,y,-x,-y
# Episode: 3409
# 27.215745426138565
# -x,-y,-y,-x,-x,y,x,-x,-x,x,y,-x
# Episode: 3719
# 28.5996971800378
# x,-y,y,x,y,-x,-y,y,-x,-y,y,y
# Episode: 12128
# 28.602919681727894
# -x,-y,-x,x,y,-y,y,x,-y,y,x,-x
#
#  run_index= 42
# Episode: 8
# 9.532587257097807
# x,d,d,d,d,d,-x,-x,x
# Episode: 16
# 10.187653510077515
# y,-y
# Episode: 25
# 11.574540763428274
# y,-x,x,-y
# Episode: 45
# 13.60119720310851
# -x,-x,x,y,d,d,-y,y,-y,x,d
# Episode: 265
# 20.89203474581286
# y,x,d,-y,d,-y,x,d,y
# Episode: 2772
# 20.896827891954022
# -x,x,y,d,-y,-x,y,-y,x
# Episode: 2857
# 26.65650664103513
# -x,-y,-y,d,-y,-x,d,x,-x,-x,y,-x
# Episode: 3252
# 27.215159259650505
# y,x,-y,y,-x,-y
# Episode: 4233
# 27.215305769063995
# x,x,-y,-x,-x,-y
# Episode: 4341
# 28.601453620770393
# d,x,y,y,-x,-y,y,-y,-x,d,-x,y
#
#  run_index= 43
# Episode: 2
# 10.187653510077515
# y,-y
# Episode: 3
# 13.405913543977034
# y,d,y,d,-x,-x,-x,y,y,x
# Episode: 381
# 20.08930642349646
# -y,-x,y,x,x,y,d,-x,-x,x,y,d
# Episode: 848
# 20.896826967500438
# -y,y,-x,y,d,-y,-x,x,x
# Episode: 1348
# 25.828828274530903
# x,d,-x,-y,d,y
# Episode: 2624
# 28.5996971800378
# d,y,-x,-y,y,-x,d,y,x,-y,y,x
# Episode: 9195
# 28.601160666322716
# y,-x,x,-y,x,-x,-y,-y,x,y,y,x
#
#  run_index= 44
# Episode: 0
# 8.801246225071123
# d
# Episode: 31
# 10.187653510077515
# y,-y
# Episode: 45
# 12.673051619059319
# y,-x,-y,y,d,-y,-x,y,x,y,-y,d
# Episode: 102
# 12.69361866716755
# -x,y,d,-x,x,-y,x
# Episode: 313
# 13.603009825580951
# x,-x,-x,x,-x,x,y,d,d,d,-y
# Episode: 440
# 27.216845415249587
# x,y,d,-y,-x,x,x,y,d,-y,-x,-x
# Episode: 8900
# 28.60380035109349
# -y,-x,-y,y,x,-x,x,y,-x,x,-y,y
#
#  run_index= 45
# Episode: 2
# 3.4735523575047917
# -x,-y,d,d,-x,x,-x,x,d,y,x,d
# Episode: 4
# 11.573738099048896
# -x,-y,-x,-y,d,d,y,x,y,-y,y,x
# Episode: 29
# 12.67244853219112
# -x,x,-y,x,d,-x,y,-x,x,d,-y,y
# Episode: 109
# 27.21552557343899
# x,-y,y,-x,y,-y
# Episode: 821
# 27.21559885230173
# -x,x,-x,-x,y,-x,x,-y,-y,x,x,-y
# Episode: 1690
# 28.60028231756181
# y,-x,y,d,x,-y,-y,x,-y,d,-x,y
#
#  run_index= 46
# Episode: 3
# 8.801246225071123
# d,d
# Episode: 5
# 12.67184689471994
# x,-y,-x,x,y,y,x,x,-x,-y,-x,-y
# Episode: 18
# 12.67244780839852
# d,x,d,x,-y,-x,-x,-y,y,-y,-x,x
# Episode: 96
# 13.58681544487998
# -x,y,-x,-y,x,d,-y,d,-x,d,x
# Episode: 338
# 27.215452299945643
# y,-x,-x,-y,-x,-x,x,-x,y,x,-x,y
# Episode: 2167
# 27.21552557343899
# x,-y,y,-x,y,-y
# Episode: 11820
# 28.602039787258455
# y,x,-x,d,-x,-y,-y,-x,y,d,-x,x
#
#  run_index= 47
# Episode: 8
# 8.801246225071123
# d
# Episode: 11
# 11.574088596342849
# y,x,-x,-y,-x,x,d,d
# Episode: 54
# 12.963241616068258
# -x,-x,x,-y,d,d,y,x
# Episode: 62
# 20.894426932
# -y,y,y,-x,-y,y,d,x,-y
# Episode: 635
# 27.215452299945643
# -y,-x,y,y,-x,-y
# Episode: 3275
# 28.601746661065533
# x,d,y,x,-x,-y,-x,-x,x,-y,d,y
#
#  run_index= 48
# Episode: 2
# 9.900025819363979
# -x,x,d
# Episode: 4
# 10.187653510077515
# y,-y
# Episode: 46
# 11.287813899578557
# -x,x,x,-x,-y,-y,d,y,d,y,-y,y
# Episode: 58
# 12.671847981331114
# -y,x,d,y,-y,x,y,-x,d,-x,y,y
# Episode: 70
# 12.673050531812446
# -x,-y,d,-x,-x,-y,d,-y,-y,x,-y,-y
# Episode: 132
# 12.695426932144628
# x,-x,-x,x,y,d,-y
# Episode: 212
# 12.956025930612599
# y,-x,d,y,x,d,-y,x
# Episode: 288
# 13.407720445498322
# y,-x,x,-y,x,-x,x,-x,-y,y
# Episode: 495
# 18.70120517898922
# y,-x,-y,-x,y,x
# Episode: 717
# 27.215012771698877
# -y,y,x,-y,y,-x
# Episode: 1107
# 27.215452299945643
# -y,x,y,y,x,-y
# Episode: 3081
# 27.21552557343899
# y,x,x,-x,-x,y,x,-x,-y,-y,-x,x
# Episode: 3632
# 28.603506708454468
# -x,x,-x,-y,-x,-x,-y,-y,-y,x,-y,-y
#
#  run_index= 49
# Episode: 14
# 10.187653510077515
# -y,y
# Episode: 22
# 12.098439467549317
# -y,-x,-x,-y,d,x,d,x,d
# Episode: 136
# 18.701657064379848
# x,x,-x,x,y,-x,d,-x,d,y,-y,y
# Episode: 162
# 20.086897010784284
# -y,x,y,d,x,-y,x,-y,-x,d,-x,-y
# Episode: 317
# 20.088704040884632
# y,d,-x,-y,y,d,-y,x,-x,-y,-x,y
# Episode: 489
# 27.215232511674124
# -y,x,x,-y,-x,-x
# Episode: 1241
# 27.21552557343899
# -x,y,-y,x,-y,y
# Episode: 3072
# 28.604094079983838
# y,-y,-x,x,-y,-x,x,-x,-y,y,x,y
#
#  run_index= 50
# Episode: 5
# 25.383656607906588
# -y,-x,d,-y,y,-y,y,x,d,y,y,-y
# Episode: 285
# 25.828864898530615
# -y,-x,d,x,y,d
# Episode: 1053
# 27.215159259650505
# -y,-y,x,y,y,x
# Episode: 2904
# 27.215452299945643
# y,x,-y,-y,x,y
# Episode: 3530
# 27.21559885230173
# x,y,-y,-y,-y,-x,-y,y,-x,-x,-y,-y
# Episode: 12033
# 28.603506708454468
# -x,y,-y,x,-y,-y,y,x,-x,y,x,-x
#
#  run_index= 51
# Episode: 4
# 10.727017629802374
# -y,y,-x,d,-x,d,x,x,-x,-x,x,x
# Episode: 29
# 11.574540763428274
# x,-x,y,-y
# Episode: 37
# 18.70120512019963
# -y,x,y,-x,y,x
# Episode: 165
# 18.701657005563685
# -x,-x,-x,-x,-y,-x,d,x,d,-y,-y,-y
# Episode: 527
# 25.828828274530903
# x,d,-x,-y,d,y
# Episode: 3921
# 27.215452299945643
# x,y,-x,x,-y,-x
# Episode: 6422
# 28.601160666322716
# -x,d,-y,-x,y,y,-x,d,x,x,y,-x
#
#  run_index= 52
# Episode: 19
# 9.900025819361765
# d,-y,y
# Episode: 39
# 10.187653510092266
# x,-x
# Episode: 44
# 20.088101315019177
# -x,y,x,x,y,y,x,-y,-x,-y,x,-x
# Episode: 1167
# 26.037812337469212
# d,-y,d,x,y,y,-y,-y,x,-x,-x,y
# Episode: 1252
# 28.597943818980777
# x,x,d,x,y,d,y,x,y,x,x,-y
# Episode: 17830
# 28.602919681727894
# x,x,y,-x,-x,y,y,y,x,-y,-y,x
#
#  run_index= 53
# Episode: 4
# 11.014712169867458
# y,y,-y,y,-y,-y,x,-x
# Episode: 42
# 11.575343951054412
# x,x,d,y,x,x,-y,-y,d,-y,y,-y
# Episode: 50
# 27.215159259650505
# x,-x,-y,-x,-y,x,y,-y,x,y,x,-y
# Episode: 7206
# 27.215452299945643
# -y,-x,y,y,-x,-y
# Episode: 15057
# 28.60028231756181
# -x,d,y,x,x,y,-x,d,-y,-x,x,y
#
#  run_index= 54
# Episode: 6
# 3.3926767262626254
# -y,x,d,d,-x,-y,d,d,y,-y,y,y
# Episode: 9
# 8.801246225071123
# d
# Episode: 22
# 11.287361665096151
# d,x,d,y,-y,-x
# Episode: 43
# 12.02127829339995
# -y,x,d,-x,y
# Episode: 63
# 12.674857254417713
# x,x,y,d,-x,-x,-y,d,x,-x,y,y
# Episode: 168
# 12.96143253586094
# d,x,d,-y,y,-x,y,-y
# Episode: 559
# 12.963241615878879
# -x,-y,d,d,y,-x,x,x
# Episode: 724
# 20.899233174180544
# -y,d,x,-y,-y,-x,y,-x,-x
# Episode: 1082
# 27.215452299945643
# x,y,-x,x,-y,-x
# Episode: 3118
# 28.5996971800378
# -y,x,x,y,x,y,x,x,-y,-x,x,x
# Episode: 18735
# 28.601160666322716
# y,x,-x,y,-x,-x,-y,y,-x,y,y,x
#
#  run_index= 55
# Episode: 6
# 10.187653510077515
# -y,y
# Episode: 26
# 12.019472477695176
# x,-x,x,-x,y,x,-y,x,y,-x
# Episode: 32
# 12.670044512925493
# -y,d,-x,x,x,-y,d,x,y,y,y,x
# Episode: 78
# 12.671845447227621
# -x,y,x,x,d,-x,-x,d,-y,x,x,-x
# Episode: 236
# 12.96143253581368
# -x,-y,y,y,d,-y,x,d
# Episode: 450
# 13.404110983188483
# y,y,-y,y,-x,-y,y,-y,-y,-x
# Episode: 474
# 13.407721533649116
# y,x,y,-y,x,-x,y,-y,-x,-y
# Episode: 1233
# 27.215452299945643
# -y,-x,y,y,-x,-y
# Episode: 2367
# 27.21559885230173
# x,-y,y,x,-x,y,y,x,-y,y,-y,-y
# Episode: 15512
# 28.599112384699495
# x,-x,-y,-x,-x,y,x,y,x,-x,y,-x
# Episode: 19151
# 28.600867797672212
# x,y,-x,-x,-y,d,x,-y,d,-y,-x,-x
#
#  run_index= 56
# Episode: 1
# 10.188105333113942
# d,-x,d,x
# Episode: 14
# 12.210581179971637
# d,-y,-x,-y,-y,x,-y,-y,-y,-x,-x
# Episode: 26
# 13.396935214023848
# -x,y,x,d,y,d,-x,x,-x,-y
# Episode: 135
# 18.701205076107442
# -x,-y,-x,y,x,y
# Episode: 269
# 20.086897069538463
# x,y,-x,-y,-x,d,y,x,-y,y,-x,d
# Episode: 1724
# 27.215159259650505
# -x,y,-y,x,y,-y
# Episode: 1775
# 27.215305769063995
# -x,-y,x,x,-y,-x
# Episode: 4710
# 28.59940473962045
# y,y,-y,x,-y,-y,x,-y,-x,y,y,-x
# Episode: 9953
# 28.604681796721295
# y,x,-x,-y,x,x,-x,-y,-y,x,y,y
#
#  run_index= 57
# Episode: 4
# 8.801246225071123
# d
# Episode: 9
# 9.900025819363979
# x,-x,d
# Episode: 59
# 12.6694432358411
# d,x,y,y,y,d,-y,x,y,-y,-y,-y
# Episode: 94
# 12.673051256997761
# x,-y,-y,-x,y,-x,-x,d,y,d,-y,-y
# Episode: 165
# 12.693618667239862
# y,x,-x,d,-y,x,-x
# Episode: 175
# 13.595785475487919
# x,y,-y,y,y,-x,d,y,x,x,-y
# Episode: 431
# 27.215159259650505
# -x,x,-y,-x,x,y
# Episode: 816
# 27.215305769063995
# -y,-x,x,y,-x,x
# Episode: 3106
# 28.599989706001566
# d,-x,-y,d,-y,x,-x,-x,y,x,-x,y
# Episode: 14604
# 28.602039787258455
# x,d,x,x,y,x,x,d,-y,x,-y,-y
#
#  run_index= 58
# Episode: 8
# 11.286759305031278
# -y,y,-x,x,x,-x
# Episode: 90
# 12.021278293418408
# x,-y,y,-x,d
# Episode: 100
# 20.088704040884632
# x,-y,-x,x,-x,y,-x,x,-x,-y,x,-x
# Episode: 274
# 27.214866305202825
# -y,x,y,-y,-x,y
# Episode: 1067
# 27.21559885230173
# -y,y,y,-y,x,-y,-y,x,-x,y,y,-x
# Episode: 3421
# 28.601746661065533
# -y,-y,-x,-y,y,-x,-x,-y,-x,x,-y,x
#
#  run_index= 59
# Episode: 0
# 8.801246225071123
# d
# Episode: 6
# 11.574540763428274
# x,y,-y,-x
# Episode: 79
# 27.215159259650505
# -x,-y,y,x,y,-y
# Episode: 1267
# 27.215305769063995
# -x,-x,y,x,x,y
# Episode: 2590
# 28.597943818980777
# -x,x,-y,x,-y,d,y,-x,d,-x,x,y
# Episode: 3565
# 28.601453620770393
# -y,x,-x,-y,x,-x,-y,-x,y,y,-x,y
#
#  run_index= 60
# Episode: 11
# 9.900025819363979
# -x,x,d
# Episode: 21
# 10.187653510077515
# -x,x
# Episode: 33
# 13.595783305815607
# -x,d,x,x,-y,d,y,-x,-y,y,d
# Episode: 171
# 27.215012771698877
# y,-y,-x,y,-y,x
# Episode: 1636
# 27.21633193641931
# y,-x,d,-y,x,-x,x,-x,-y,d,-x,y
# Episode: 10934
# 28.601746661065533
# -x,x,y,x,-y,y,x,-y,y,-x,-x,-y
#
#  run_index= 61
# Episode: 0
# 11.307516445941404
# d,x,-y,y,x,-x,-x
# Episode: 38
# 26.65608775777177
# -y,d,-x,-y,d,y,x,-x,y,-y,x,y
# Episode: 927
# 27.215159259650505
# -y,x,-x,y,x,-x
# Episode: 3011
# 27.215305769063995
# x,-y,-x,-x,-y,x
# Episode: 3902
# 28.601453620770393
# -x,y,y,-x,-y,-x,-x,-y,x,x,-y,-y
#
#  run_index= 62
# Episode: 0
# 25.828938150554233
# d,x,y,d,-y,-x
# Episode: 645
# 28.603506708454468
# y,-y,-x,-y,y,x,-x,-x,-y,x,x,-y
#
#  run_index= 63
# Episode: 16
# 8.801246225071123
# d
# Episode: 26
# 10.187653510092266
# x,-x
# Episode: 30
# 13.601203748370533
# x,-y,-y,-y,x,x,x,x,-y,d,-x
# Episode: 588
# 27.215232511674124
# -x,x,y,x,-x,-y
# Episode: 1071
# 28.603506708454468
# -y,-x,x,y,-y,y,-x,y,-y,x,-x,x
#
#  run_index= 64
# Episode: 11
# 8.801246225071123
# d,d
# Episode: 23
# 10.187653510077515
# -y,y
# Episode: 28
# 11.286759305048989
# x,-x,-x,x,-y,y
# Episode: 33
# 12.672447446095333
# d,-y,d,-x,x,-x,x,x,y,-y,-x,y
# Episode: 118
# 13.5975883062126
# x,x,y,d,-x,y,-y,-x,-x,x,y
# Episode: 292
# 20.08749871705518
# -x,-y,x,-y,-x,y,d,-x,y,d,-y,x
# Episode: 934
# 20.08810196209416
# -y,y,-x,-y,x,x,-y,-y,y,x,-x,-x
# Episode: 1220
# 27.21559885230173
# x,x,y,x,x,-y,-y,-x,-x,y,x,x
# Episode: 9906
# 28.600867797672212
# -y,d,-y,-y,-x,y,y,d,x,-y,-x,-x
#
#  run_index= 65
# Episode: 3
# 9.900025819375042
# -y,d,y,-y,d,y
# Episode: 5
# 10.187653510077515
# -x,x
# Episode: 38
# 13.597588304516227
# x,y,d,-y,x,-x,-y,x,y,-x,y
# Episode: 53
# 20.896827231629945
# -x,-y,y,x,-y,d,y,x,-x
# Episode: 254
# 25.82879165187246
# d,y,-x,d,x,-y
# Episode: 2374
# 28.603506708454468
# y,-y,x,y,y,y,-x,-x,-y,-x,-x,-x
#
#  run_index= 66
# Episode: 10
# 10.187653510077515
# -x,x
# Episode: 16
# 10.187653510092266
# x,-x
# Episode: 20
# 12.669445041641989
# d,d,x,y,-y,-y,x,x,-x,y,-x,y
# Episode: 47
# 12.670645790322522
# x,d,-y,-x,x,-x,-x,y,-x,-y,-y,d
# Episode: 56
# 26.037631811687383
# d,-x,d,-y,x,-x,x,-x,y,y,-y,x
# Episode: 2561
# 27.215232511674124
# -y,-x,-y,-y,x,-y,-y,-x,y,-y,-x,y
# Episode: 3601
# 27.21552557343899
# -x,-y,y,x,y,-y,y,-y,x,y,-y,-x
# Episode: 8872
# 28.600867797672212
# -y,x,-x,-y,-x,y,x,-x,y,-x,x,-x
#
#  run_index= 67
# Episode: 3
# 8.801246225071123
# d
# Episode: 15
# 10.074950359993817
# d,x,d,-x,d
# Episode: 22
# 10.634274878464927
# -x,y,-y,d,x
# Episode: 51
# 12.668845929544286
# x,x,-x,-x,y,d,x,y,-x,-y,d,-x
# Episode: 90
# 12.671847619068297
# d,y,-x,-y,y,y,x,-y,d,x,y,-y
# Episode: 174
# 12.957824163360392
# d,-x,x,-y,-x,d,x,y
# Episode: 201
# 27.215452299945643
# y,x,x,-y,x,x,-x,x,y,x,-x,y
# Episode: 12893
# 28.601746661065533
# -y,x,-x,y,-x,x,-y,x,y,y,x,-y
#
#  run_index= 68
# Episode: 6
# 10.187653510077515
# -x,x
# Episode: 42
# 11.286909997021345
# y,x,-x,-y,y,x,-x,y,-y,-y,-y,y
# Episode: 132
# 11.574741409362387
# y,y,d,-x,d,x,x,-x,x,-y,-y,x
# Episode: 147
# 12.02127829339995
# -x,x,y,d,-y
# Episode: 322
# 12.672448532120324
# y,-y,-x,y,x,x,y,d,-y,y,d,-x
# Episode: 354
# 13.404113152533048
# -y,-x,y,-x,-y,-y,y,x,-y,y
# Episode: 595
# 13.40591571524534
# y,y,-x,-y,-x,-y,-x,y,x,-x
# Episode: 697
# 26.655334209781156
# y,-x,-y,d,-y,x,d,x,-y,-y,-x,-y
# Episode: 809
# 27.215305769063995
# x,y,-y,-x,y,-y
# Episode: 3745
# 27.215452299945643
# -y,x,y,y,x,-y
# Episode: 5039
# 27.215672136534664
# y,-y,x,-y,y,y,y,x,-y,-y,x,-x
# Episode: 8066
# 28.601746661065533
# d,-x,y,-x,x,y,d,y,-y,-x,-y,-y
#
#  run_index= 69
# Episode: 3
# 9.628090182984486
# -x,x,d,d
# Episode: 36
# 18.701740380945022
# x,x,-x,-y,-x,-y,x,d,y
# Episode: 331
# 18.701957586603257
# -y,y,x,-x,-x,y,-x,y,x,x,x,y
# Episode: 729
# 20.086897950851586
# x,y,-x,-y,x,x,y,-x,-x,y,-x,y
# Episode: 1721
# 27.214866305202825
# y,-y,-x,-y,y,x
# Episode: 2340
# 28.601453620770393
# x,y,y,-x,y,d,x,x,-y,x,-x,d
#
#  run_index= 70
# Episode: 15
# 10.187653510077515
# -x,x
# Episode: 32
# 10.634274878451093
# -x,-y,y,d,x
# Episode: 42
# 11.651252119642837
# x,d,x,x,-x,-x,-y,-x,-y,x,y
# Episode: 83
# 12.671847257336267
# -x,-y,y,x,d,-y,x,-x,d,-x,x,y
# Episode: 108
# 12.959627808608035
# -x,x,-y,x,x,-x,-x,y
# Episode: 364
# 27.214866305202825
# -y,x,y,-y,-x,y
# Episode: 828
# 27.215305769063995
# y,-y,x,y,-y,-x
# Episode: 2711
# 27.21552557343899
# y,-x,y,y,-y,y,x,-y,-y,x,x,-y
# Episode: 9914
# 28.603506708454468
# x,-x,-y,y,x,-y,y,-y,-x,-x,-y,x
#
#  run_index= 71
# Episode: 1
# 10.187653510077515
# -x,x
# Episode: 33
# 12.02127829339995
# -y,x,d,-x,y
# Episode: 100
# 12.690011916386508
# -y,d,-x,y,-x,-y,x
# Episode: 280
# 13.402310585115655
# y,x,d,y,-y,-x,y,d,-y,-y
# Episode: 396
# 20.08930624680874
# y,-x,x,-x,-y,x,d,-y,x,d,-x,-x
# Episode: 676
# 27.215159259650505
# x,-y,x,-x,y,-x
# Episode: 2538
# 27.215232511674124
# y,x,-x,-y,-x,x
# Episode: 9868
# 28.59940473962045
# y,-x,y,x,x,-y,-x,-x,x,-y,x,x
# Episode: 14539
# 28.602039787258455
# -x,y,d,-y,-y,x,-y,y,d,-x,y,x
#
#  run_index= 72
# Episode: 15
# 10.187653510077515
# -x,x
# Episode: 25
# 12.671245981503201
# -x,d,y,-x,-y,y,-y,y,x,d,-y,x
# Episode: 82
# 12.695424752711087
# d,x,-y,d,y,d,-x
# Episode: 432
# 27.215159259650505
# -x,x,-y,-x,x,y
# Episode: 2840
# 28.603506708454468
# -x,-x,-y,-x,-x,-x,y,y,-x,y,y,-y
#
#  run_index= 73
# Episode: 11
# 10.187653510077515
# -y,y
# Episode: 41
# 12.019021736369517
# y,x,-y,x,-x,d,-x,d,-y,x
# Episode: 62
# 12.097236013727674
# y,d,y,-x,-y,-x,-x,y,x
# Episode: 78
# 26.656841874025194
# y,-y,d,-x,-y,-y,y,-x,x,y,d,x
# Episode: 366
# 28.598527931146915
# y,y,-x,y,y,d,y,x,d,x,y,x
# Episode: 1229
# 28.601746661065533
# -x,y,-x,x,y,x,y,-y,-x,-y,-y,x
#
#  run_index= 74
# Episode: 2
# 12.670644344002394
# -y,-x,-y,y,-y,-y,d,-x,y,d,y,y
# Episode: 36
# 12.695426932434398
# -x,y,-y,y,-y,x,d
# Episode: 236
# 20.896827231629945
# -x,-y,d,-y,x,-x,-x,y,y
# Episode: 358
# 27.215159259650505
# -x,x,-y,-x,x,y
# Episode: 775
# 28.600867797672212
# x,x,-y,-x,x,-x,y,x,-x,-y,-x,-y
# [12151, 6834, 15869, 5286, 1244, 755, 2102, 3456, 676, 2489, 391, 8978, 6084, 4307, 2172, 1705, 5314, 9353, 5202, 1981, 2517, 809, 2927, 9730, 13261, 4003, 9657, 7202, 16383, 1620, 1860, 17751, 847, 5793, 12695, 13219, 2985, 1727, 6724, 9113, 4658, 12128, 4341, 9195, 8900, 1690, 11820, 3275, 3632, 3072, 12033, 6422, 17830, 15057, 18735, 19151, 9953, 14604, 3421, 3565, 10934, 3902, 645, 1071, 9906, 2374, 8872, 12893, 8066, 2340, 9914, 14539, 2840, 1229, 775]
# []
# time=9264.474686
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: DeprecationWarning: time.clock has been deprecated in Python 3.3 and will be removed from Python 3.8: use time.perf_counter or time.process_time instead

# %% [markdown]
# ## Plot

# %%
# avr=[]
# temp=0
# for i in range(len(reward_list)):
#     temp += reward_list[i]
#     avr.append(temp/(i+1))

# %%
# np.savetxt('DQLearning_pw0_elite_re25.csv',np.array([np.asarray(reward_list),np.asarray(avr)]).T,fmt=['%.7f','%.7f'],delimiter=',',header="rew,avrrew") 

# fig, ax = plt.subplots(figsize=(5,4),tight_layout=True)

# ax.plot(reward_list,'+')
# ax.plot(avr)


# # ax.set_xscale('log')

# ax.set(xlabel='Episode', ylabel='Reward',
#        title='Jt=8.18e-3')        ### The 12 pulse sequence is compared with the 6 pulse sequence
#                                    ### We regard the 6 pulse sequence is T long, the 12 pulse sequence is 2T long 

# plt.legend(['reward', 'average reward'], loc='best')

# plt.savefig('DQLearning_pw0_elite_re25.eps', dpi=fig.dpi, bbox_inches='tight')
# Out:
#   3%|▎         | 3222/100000 [01:10<28:57, 55.71it/s]

# %% [markdown]
# ###
